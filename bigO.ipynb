# %% [markdown]
# # **Guía Completa sobre la Notación Big O**
#
# La **notación Big O** es una herramienta fundamental en la informática y la ciencia de datos. Nos permite medir el rendimiento de los algoritmos en función del tamaño de la entrada (*n*), enfocándonos en cómo crece el tiempo de ejecución o el uso de memoria cuando los datos aumentan.
#
# ## **¿Por qué es importante la Notación Big O?**
#
# Cuando diseñamos o elegimos un algoritmo, queremos que sea lo más eficiente posible. Big O nos ayuda a comparar diferentes soluciones y entender cuál se comportará mejor a medida que trabajemos con más datos.
#
# ---
#
# ## **Principales Clases de Complejidad**
#
# A continuación, te presentamos las complejidades más comunes en los algoritmos:
#
# | Notación | Nombre | Ejemplo |
# |----------|--------|---------|
# | **O(1)** | Constante | Acceder a un elemento de un array por índice |
# | **O(log n)** | Logarítmica | Búsqueda binaria |
# | **O(n)** | Lineal | Búsqueda secuencial |
# | **O(n log n)** | Cuasilineal | Ordenamiento rápido (QuickSort) |
# | **O(n²)** | Cuadrática | Ordenamiento burbuja (Bubble Sort) |
# | **O(2ⁿ)** | Exponencial | Algoritmos de fuerza bruta en problemas NP |
#
# ---
#
# ## **Ejemplos con Código**
#
# ### **Ejemplo de O(1) – Tiempo Constante**
# Este código siempre toma el mismo tiempo, sin importar el tamaño de la lista.
#
# ```python
# def obtener_primero(lista):
#     return lista[0]  # Siempre accede al primer elemento
# ```
# 📌 **Independientemente del tamaño de `lista`, solo hace una operación.**
#
# ---
#
# ### **Ejemplo de O(n) – Tiempo Lineal**
# Recorrer una lista es una operación de **O(n)**, ya que aumenta proporcionalmente con `n`.
#
# ```python
# def buscar_elemento(lista, objetivo):
#     for elemento in lista:
#         if elemento == objetivo:
#             return True
#     return False
# ```
# 📌 **Si `n` es grande, el tiempo de ejecución también lo será.**
#
# ---
#
# ### **Ejemplo de O(n²) – Tiempo Cuadrático**
# Este código usa un doble bucle anidado, lo que hace que su tiempo de ejecución crezca cuadráticamente.
#
# ```python
# def pares_unicos(lista):
#     for i in range(len(lista)):
#         for j in range(i + 1, len(lista)):
#             print(lista[i], lista[j])  # Comparación de cada elemento con todos los demás
# ```
# 📌 **Si `n = 1000`, las operaciones serán alrededor de `1000² = 1,000,000`.**
#
# ---
#
# ## **Diagrama de Comparación de Complejidades**
#
# 📈 **Gráfico de crecimiento de Big O**

# %%
import numpy as np
import matplotlib.pyplot as plt

# Definir el rango de valores de n
n = np.linspace(1, 10, 100)

# Definir las funciones de complejidad
O_1 = np.ones_like(n)                # O(1) - constante
O_log_n = np.log(n)                  # O(log n) - logarítmica
O_n = n                               # O(n) - lineal
O_n_log_n = n * np.log(n)            # O(n log n) - cuasilineal
O_n2 = n**2                          # O(n^2) - cuadrática
O_2n = 2**n                          # O(2^n) - exponencial

# Graficar las funciones
plt.figure(figsize=(10, 6))
plt.plot(n, O_1, label="O(1)", linewidth=2)
plt.plot(n, O_log_n, label="O(log n)", linewidth=2)
plt.plot(n, O_n, label="O(n)", linewidth=2)
plt.plot(n, O_n_log_n, label="O(n log n)", linewidth=2)
plt.plot(n, O_n2, label="O(n²)", linewidth=2)
plt.plot(n, O_2n, label="O(2ⁿ)", linewidth=2, linestyle="dashed")

# Configuración del gráfico
plt.ylim(0, 100)  # Limitar el eje Y para mejor visualización
plt.xlabel("Tamaño de Entrada (n)")
plt.ylabel("Operaciones")
plt.title("Crecimiento de Complejidades en Notación Big O")
plt.legend()
plt.grid(True)

# Mostrar la gráfica
plt.show()

# %% [markdown]
# 💡 **Cuanto más rápido crece la función, menos eficiente es el algoritmo en datos grandes.**
#
# Si necesitas comparar algoritmos para un problema, Big O te ayuda a elegir el más eficiente.
#
# ---
#
# ## **Conclusión**
#
# La notación Big O es una herramienta clave para entender la eficiencia de los algoritmos. Conocer las complejidades más comunes te permitirá diseñar soluciones óptimas y tomar decisiones informadas al programar. ¡Recuerda siempre analizar el rendimiento antes de elegir un algoritmo! 🚀
