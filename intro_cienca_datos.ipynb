# %% [markdown]
# # Introduccion a la ciencia de datos
#
# ## ¿Que es?
#
#
# ## ¿Para que sirve?
#
#
#
# ## ¿Cómo se hace?

# %%
# importar librerias

import numpy as np
import pandas as pd

# %% [markdown]
# se abre un archivo tipo CSV (Coma Separated Values)

# %%
df=pd.read_csv('dirty_dataset.csv')

# %%
df.head(15)
# Out:
#    Customer_ID          Name                 Email  Purchase_Amount  \
# 0         c001      John Doe    john.doe@email.com           2000.0
# 1         C001    Jane Smith  jane.smith@email.com            100.0
# 2         C001    JANE SMITH  jane.smith@EMAIL.com            -10.0
# 3         c001    Mike Brown   mikebrown@email.com              NaN
# 4         C003    mike brown                   NaN           2000.0
# 5         C002  Samantha Lee    samantha@email.com             50.0
# 6         C002   Samanth Lee     sam.lee@email.com           2000.0
# 7         C002      John Doe    john.doe@email.com            -10.0
# 8         c001    Jane Smith  jane.smith@email.com              NaN
# 9         C001    JANE SMITH  jane.smith@EMAIL.com            100.0
# 10        c001    Mike Brown   mikebrown@email.com            -10.0
# 11        c001    mike brown                   NaN            -10.0
# 12        C005  Samantha Lee    samantha@email.com             50.0
# ...

# %% [markdown]
# se revisa el dataframe

# %%
df.tail()
# Out:
#    Customer_ID        Name                 Email  Purchase_Amount  \
# 50        c001    John Doe    john.doe@email.com           2000.0
# 51        C001  Jane Smith  jane.smith@email.com            100.0
# 52        C001  JANE SMITH  jane.smith@EMAIL.com            -10.0
# 53        c001  Mike Brown   mikebrown@email.com              NaN
# 54        C003  mike brown                   NaN           2000.0
#
#    Purchase_Date Product_Category Quantity Discount_Applied Store_Location
# 50    2024-01-01      Electronics      NaN               no       New York
# 51    01/02/2024         Clothing        2             True    Los Angeles
# 52    2024-01-03         clothing      two               no    los angeles
# 53    2024-01-04        Furniture      two            False        Chicago
# 54    01-05-2024        FURNITURE      two             True        CHICAGO

# %%
df
# Out:
#    Customer_ID          Name                 Email  Purchase_Amount  \
# 0         c001      John Doe    john.doe@email.com           2000.0
# 1         C001    Jane Smith  jane.smith@email.com            100.0
# 2         C001    JANE SMITH  jane.smith@EMAIL.com            -10.0
# 3         c001    Mike Brown   mikebrown@email.com              NaN
# 4         C003    mike brown                   NaN           2000.0
# 5         C002  Samantha Lee    samantha@email.com             50.0
# 6         C002   Samanth Lee     sam.lee@email.com           2000.0
# 7         C002      John Doe    john.doe@email.com            -10.0
# 8         c001    Jane Smith  jane.smith@email.com              NaN
# 9         C001    JANE SMITH  jane.smith@EMAIL.com            100.0
# 10        c001    Mike Brown   mikebrown@email.com            -10.0
# 11        c001    mike brown                   NaN            -10.0
# 12        C005  Samantha Lee    samantha@email.com             50.0
# ...

# %% [markdown]
# se revisa en tamaño del dataframe

# %%
df.shape
# Out:
# (55, 9)

# %% [markdown]
# obtener estadisticas generales del dataframe

# %%
# df.describe()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Customer_ID       55 non-null     object
#  1   Name              55 non-null     object
#  2   Email             47 non-null     object
#  3   Purchase_Amount   42 non-null     float64
#  4   Purchase_Date     48 non-null     object
#  5   Product_Category  55 non-null     object
#  6   Quantity          45 non-null     object
#  7   Discount_Applied  44 non-null     object
#  8   Store_Location    55 non-null     object
# dtypes: float64(1), object(8)
# memory usage: 4.0+ KB

# %% [markdown]
# se verifica cuantos NaN hay en el dataset existen

# %%
df.isna().sum()
# Out:
# Customer_ID          0
# Name                 0
# Email                8
# Purchase_Amount     13
# Purchase_Date        7
# Product_Category     0
# Quantity            10
# Discount_Applied    11
# Store_Location       0
# dtype: int64

# %% [markdown]
# buscar por nulos

# %%
df.isnull().sum()
# Out:
# Customer_ID          0
# Name                 0
# Email                8
# Purchase_Amount     13
# Purchase_Date        7
# Product_Category     0
# Quantity            10
# Discount_Applied    11
# Store_Location       0
# dtype: int64
